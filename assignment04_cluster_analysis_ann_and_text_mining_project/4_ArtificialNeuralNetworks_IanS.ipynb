# %%
from keras import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, classification_report

# Encode text values to dummy variables(i.e. [1,0,0],[0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = "{}-{}".format(name, x)
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)

# Encode text values to indexes(i.e. [1],[2],[3] for red,green,blue).
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    df[name] = le.fit_transform(df[name])
    return le.classes_

# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
import collections
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column. 
    target_type = df[target].dtypes
    target_type = target_type[0] if isinstance(target_type, collections.abc.Sequence) else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    if target_type in (np.int64, np.int32):
        # Classification
        dummies = pd.get_dummies(df[target])
        return df[result].values.astype(np.float32), dummies.values.astype(np.float32)
    else:
        # Regression
        return df[result].values.astype(np.float32), df[target].values.astype(np.float32)

# %%
#Loading the dataset
data_df = pd.read_csv('data/admission_data_set.csv',header='infer')

# %%
#Dropping unecessary Columns
data_df = data_df.drop('SOP', axis=1)
data_df = data_df.drop('LOR', axis=1)
data_df = data_df.drop('CGPA', axis=1)

# %%
data_df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  Research  \
# 0             1        337          118                  4         1
# 1             2        324          107                  4         1
# 2             3        316          104                  3         1
# 3             4        322          110                  3         1
# 4             5        314          103                  2         0
# ..          ...        ...          ...                ...       ...
# 495         496        332          108                  5         1
# 496         497        337          117                  5         1
# 497         498        330          120                  5         1
# 498         499        312          103                  4         0
# 499         500        327          113                  4         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# 3               0.80
# 4               0.65
# ..               ...
# 495             0.87
# 496             0.96
# 497             0.93
# 498             0.73
# 499             0.84
#
# [500 rows x 6 columns]

# %%
#Loading the test data
testdata=data_df[0:100]

testdata
# Out:
#     Serial No.  GRE Score  TOEFL Score  University Rating  Research  \
# 0            1        337          118                  4         1
# 1            2        324          107                  4         1
# 2            3        316          104                  3         1
# 3            4        322          110                  3         1
# 4            5        314          103                  2         0
# ..         ...        ...          ...                ...       ...
# 95          96        304          100                  4         0
# 96          97        306          100                  2         0
# 97          98        331          120                  3         1
# 98          99        332          119                  4         1
# 99         100        323          113                  3         1
#
#     Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65
# ..              ...
# 95             0.42
# 96             0.48
# 97             0.86
# 98             0.90
# 99             0.79
#
# [100 rows x 6 columns]

# %%
#Encoding the data based on the Research Column
encode_text_index(testdata,'Research')
# Out:
# C:\Users\mrpan\AppData\Local\Temp\ipykernel_17428\4231616319.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = le.fit_transform(df[name])
# array([0, 1], dtype=int64)

# %%
#Splitting the data by the Research Column
X,Y = to_xy(data_df,'Research')
testX,testY=to_xy(data_df,'Research')

# %%
#Generating the ANN model
model = Sequential()
model.add(Dense(12, input_dim = X.shape[1], activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam')
model.fit(X,Y,verbose=2, epochs=100)
# Out:
# Epoch 1/100
# 16/16 - 1s - loss: 29.8918 - 1s/epoch - 65ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 17.3643 - 36ms/epoch - 2ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 9.3011 - 43ms/epoch - 3ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 4.2254 - 34ms/epoch - 2ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 1.7390 - 33ms/epoch - 2ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.8819 - 33ms/epoch - 2ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.7283 - 35ms/epoch - 2ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.6925 - 36ms/epoch - 2ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.6842 - 35ms/epoch - 2ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.6842 - 36ms/epoch - 2ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.6854 - 34ms/epoch - 2ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.6854 - 35ms/epoch - 2ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.6843 - 80ms/epoch - 5ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.6837 - 41ms/epoch - 3ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.6853 - 41ms/epoch - 3ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.6859 - 32ms/epoch - 2ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.6858 - 28ms/epoch - 2ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.6834 - 31ms/epoch - 2ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.6842 - 36ms/epoch - 2ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.6852 - 39ms/epoch - 2ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.6863 - 38ms/epoch - 2ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.6858 - 34ms/epoch - 2ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.6849 - 34ms/epoch - 2ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.6850 - 35ms/epoch - 2ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.6843 - 32ms/epoch - 2ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.6847 - 32ms/epoch - 2ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.6855 - 32ms/epoch - 2ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.6845 - 35ms/epoch - 2ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.6844 - 33ms/epoch - 2ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.6840 - 33ms/epoch - 2ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.6873 - 32ms/epoch - 2ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.6846 - 36ms/epoch - 2ms/step
# Epoch 33/100
# 16/16 - 0s - loss: 0.6836 - 82ms/epoch - 5ms/step
# Epoch 34/100
# 16/16 - 0s - loss: 0.6841 - 61ms/epoch - 4ms/step
# Epoch 35/100
# 16/16 - 0s - loss: 0.6843 - 48ms/epoch - 3ms/step
# Epoch 36/100
# 16/16 - 0s - loss: 0.6840 - 31ms/epoch - 2ms/step
# Epoch 37/100
# 16/16 - 0s - loss: 0.6840 - 29ms/epoch - 2ms/step
# Epoch 38/100
# 16/16 - 0s - loss: 0.6843 - 30ms/epoch - 2ms/step
# Epoch 39/100
# 16/16 - 0s - loss: 0.6850 - 36ms/epoch - 2ms/step
# Epoch 40/100
# 16/16 - 0s - loss: 0.6850 - 38ms/epoch - 2ms/step
# Epoch 41/100
# 16/16 - 0s - loss: 0.6844 - 38ms/epoch - 2ms/step
# Epoch 42/100
# 16/16 - 0s - loss: 0.6843 - 34ms/epoch - 2ms/step
# Epoch 43/100
# 16/16 - 0s - loss: 0.6853 - 35ms/epoch - 2ms/step
# Epoch 44/100
# 16/16 - 0s - loss: 0.6847 - 37ms/epoch - 2ms/step
# Epoch 45/100
# 16/16 - 0s - loss: 0.6845 - 37ms/epoch - 2ms/step
# Epoch 46/100
# 16/16 - 0s - loss: 0.6848 - 34ms/epoch - 2ms/step
# Epoch 47/100
# 16/16 - 0s - loss: 0.6844 - 34ms/epoch - 2ms/step
# Epoch 48/100
# 16/16 - 0s - loss: 0.6845 - 38ms/epoch - 2ms/step
# Epoch 49/100
# 16/16 - 0s - loss: 0.6846 - 34ms/epoch - 2ms/step
# Epoch 50/100
# 16/16 - 0s - loss: 0.6865 - 34ms/epoch - 2ms/step
# Epoch 51/100
# 16/16 - 0s - loss: 0.6844 - 35ms/epoch - 2ms/step
# Epoch 52/100
# 16/16 - 0s - loss: 0.6850 - 36ms/epoch - 2ms/step
# Epoch 53/100
# 16/16 - 0s - loss: 0.6846 - 37ms/epoch - 2ms/step
# Epoch 54/100
# 16/16 - 0s - loss: 0.6840 - 36ms/epoch - 2ms/step
# Epoch 55/100
# 16/16 - 0s - loss: 0.6857 - 33ms/epoch - 2ms/step
# Epoch 56/100
# 16/16 - 0s - loss: 0.6844 - 32ms/epoch - 2ms/step
# Epoch 57/100
# 16/16 - 0s - loss: 0.6835 - 34ms/epoch - 2ms/step
# Epoch 58/100
# 16/16 - 0s - loss: 0.6836 - 36ms/epoch - 2ms/step
# Epoch 59/100
# 16/16 - 0s - loss: 0.6840 - 34ms/epoch - 2ms/step
# Epoch 60/100
# 16/16 - 0s - loss: 0.6848 - 44ms/epoch - 3ms/step
# Epoch 61/100
# 16/16 - 0s - loss: 0.6844 - 33ms/epoch - 2ms/step
# Epoch 62/100
# 16/16 - 0s - loss: 0.6843 - 35ms/epoch - 2ms/step
# Epoch 63/100
# 16/16 - 0s - loss: 0.6835 - 32ms/epoch - 2ms/step
# Epoch 64/100
# 16/16 - 0s - loss: 0.6838 - 36ms/epoch - 2ms/step
# Epoch 65/100
# 16/16 - 0s - loss: 0.6855 - 33ms/epoch - 2ms/step
# Epoch 66/100
# 16/16 - 0s - loss: 0.6872 - 34ms/epoch - 2ms/step
# Epoch 67/100
# 16/16 - 0s - loss: 0.6843 - 36ms/epoch - 2ms/step
# Epoch 68/100
# 16/16 - 0s - loss: 0.6830 - 35ms/epoch - 2ms/step
# Epoch 69/100
# 16/16 - 0s - loss: 0.6866 - 35ms/epoch - 2ms/step
# Epoch 70/100
# 16/16 - 0s - loss: 0.6871 - 36ms/epoch - 2ms/step
# Epoch 71/100
# 16/16 - 0s - loss: 0.6855 - 34ms/epoch - 2ms/step
# Epoch 72/100
# 16/16 - 0s - loss: 0.6849 - 34ms/epoch - 2ms/step
# Epoch 73/100
# 16/16 - 0s - loss: 0.6856 - 34ms/epoch - 2ms/step
# Epoch 74/100
# 16/16 - 0s - loss: 0.6852 - 34ms/epoch - 2ms/step
# Epoch 75/100
# 16/16 - 0s - loss: 0.6860 - 33ms/epoch - 2ms/step
# Epoch 76/100
# 16/16 - 0s - loss: 0.6857 - 34ms/epoch - 2ms/step
# Epoch 77/100
# 16/16 - 0s - loss: 0.6857 - 36ms/epoch - 2ms/step
# Epoch 78/100
# 16/16 - 0s - loss: 0.6844 - 37ms/epoch - 2ms/step
# Epoch 79/100
# 16/16 - 0s - loss: 0.6844 - 34ms/epoch - 2ms/step
# Epoch 80/100
# 16/16 - 0s - loss: 0.6858 - 37ms/epoch - 2ms/step
# Epoch 81/100
# 16/16 - 0s - loss: 0.6854 - 36ms/epoch - 2ms/step
# Epoch 82/100
# 16/16 - 0s - loss: 0.6852 - 37ms/epoch - 2ms/step
# Epoch 83/100
# 16/16 - 0s - loss: 0.6845 - 34ms/epoch - 2ms/step
# Epoch 84/100
# 16/16 - 0s - loss: 0.6851 - 35ms/epoch - 2ms/step
# Epoch 85/100
# 16/16 - 0s - loss: 0.6854 - 35ms/epoch - 2ms/step
# Epoch 86/100
# 16/16 - 0s - loss: 0.6854 - 36ms/epoch - 2ms/step
# Epoch 87/100
# 16/16 - 0s - loss: 0.6846 - 37ms/epoch - 2ms/step
# Epoch 88/100
# 16/16 - 0s - loss: 0.6845 - 35ms/epoch - 2ms/step
# Epoch 89/100
# 16/16 - 0s - loss: 0.6861 - 36ms/epoch - 2ms/step
# Epoch 90/100
# 16/16 - 0s - loss: 0.6845 - 36ms/epoch - 2ms/step
# Epoch 91/100
# 16/16 - 0s - loss: 0.6849 - 37ms/epoch - 2ms/step
# Epoch 92/100
# 16/16 - 0s - loss: 0.6852 - 34ms/epoch - 2ms/step
# Epoch 93/100
# 16/16 - 0s - loss: 0.6857 - 33ms/epoch - 2ms/step
# Epoch 94/100
# 16/16 - 0s - loss: 0.6838 - 34ms/epoch - 2ms/step
# Epoch 95/100
# 16/16 - 0s - loss: 0.6851 - 37ms/epoch - 2ms/step
# Epoch 96/100
# 16/16 - 0s - loss: 0.6841 - 36ms/epoch - 2ms/step
# Epoch 97/100
# 16/16 - 0s - loss: 0.6842 - 33ms/epoch - 2ms/step
# Epoch 98/100
# 16/16 - 0s - loss: 0.6839 - 35ms/epoch - 2ms/step
# Epoch 99/100
# 16/16 - 0s - loss: 0.6842 - 35ms/epoch - 2ms/step
# Epoch 100/100
# 16/16 - 0s - loss: 0.6846 - 36ms/epoch - 2ms/step

# %%
pred = model.predict(testX)
print(pred[0])
# Out:
# 16/16 [==============================] - 0s 2ms/step
# [0.3582261  0.64177394]

# %%
pred = np.argmax(pred, axis=1)

# %%
true = np.argmax(testY, axis=1)

# %%
print('Accuracy on test data is %.2f' % (accuracy_score(true, pred)))
# Out:
# Accuracy on test data is 0.57

# %%
print(classification_report(true,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.05      0.09       220
#            1       0.57      0.98      0.72       280
#
#     accuracy                           0.57       500
#    macro avg       0.62      0.51      0.40       500
# weighted avg       0.61      0.57      0.44       500
