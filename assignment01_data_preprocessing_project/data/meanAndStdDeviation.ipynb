# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Set up the file path
path = "./data/"
filename_read = os.path.join(path, "uci_heartDisease_Spliting.csv")

# Read the CSV file into a DataFrame, handling missing values
df = pd.read_csv(filename_read, na_values=['NA', '?'])


# Split the DataFrame into two random subsets
df1, df2 = train_test_split(df, test_size=0.5, random_state=42)  # 50% split; you can adjust test_size as needed

# Calculate and print the mean and standard deviation of each subset
mean_df1 = df1.mean()
std_dev_df1 = df1.std()
mean_df2 = df2.mean()
std_dev_df2 = df2.std()

print(f"Mean of Subset 1:\n{mean_df1}")
print(f"Standard Deviation of Subset 1:\n{std_dev_df1}")
print(f"Mean of Subset 2:\n{mean_df2}")
print(f"Standard Deviation of Subset 2:\n{std_dev_df2}")
# Out:
# Mean of Subset 1:
# age          54.960265
# sex           0.635762
# cp            3.158940
# trestbps    132.569536
# chol        244.311258
# fbs           0.139073
# restecg       1.013245
# thalach     149.788079
# exang         0.331126
# oldpeak       0.956291
# slope         1.562914
# ca            0.651007
# thal          4.604027
# num           0.927152
# dtype: float64
# Standard Deviation of Subset 1:
# age          9.383589
# sex          0.482817
# cp           0.931613
# trestbps    18.629192
# chol        45.195455
# fbs          0.347174
# restecg      0.999912
# thalach     21.720224
# exang        0.472184
# oldpeak      1.190942
# slope        0.606368
# ca           0.936686
# thal         1.920089
# num          1.254854
# dtype: float64
# Mean of Subset 2:
# age          53.921053
# sex           0.723684
# cp            3.157895
# trestbps    130.815789
# chol        249.059211
# fbs           0.157895
# restecg       0.967105
# thalach     149.427632
# exang         0.322368
# oldpeak       1.122368
# slope         1.638158
# ca            0.693333
# thal          4.861842
# num           0.947368
# dtype: float64
# Standard Deviation of Subset 2:
# age          8.682422
# sex          0.448653
# cp           0.990720
# trestbps    16.529092
# chol        57.630616
# fbs          0.365848
# restecg      0.992807
# thalach     24.037940
# exang        0.468928
# oldpeak      1.128452
# slope        0.625605
# ca           0.940845
# thal         1.956647
# num          1.205888
# dtype: float64
