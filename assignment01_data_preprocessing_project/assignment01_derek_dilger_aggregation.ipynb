# %% [markdown]
# # Our implementation of Aggregation

# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
import datetime

# %%
TIME = pd.read_csv("TIME.csv") #obtaining our dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\repo\csc177-group-project\assignment01_data_preprocessing_project\assignment01_derek_dilger_aggregation.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/repo/csc177-group-project/assignment01_data_preprocessing_project/assignment01_derek_dilger_aggregation.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> TIME = pd.read_csv("TIME.csv") #obtaining our dataset
#
# File d:\repo\csc177-group-project\assignment01_data_preprocessing_project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File d:\repo\csc177-group-project\assignment01_data_preprocessing_project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File d:\repo\csc177-group-project\assignment01_data_preprocessing_project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File d:\repo\csc177-group-project\assignment01_data_preprocessing_project\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File d:\repo\csc177-group-project\assignment01_data_preprocessing_project\.venv\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TIME.csv'

# %%
TIME #preview of data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\repo\csc177-group-project\assignment01_data_preprocessing_project\assignment01_derek_dilger_aggregation.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/repo/csc177-group-project/assignment01_data_preprocessing_project/assignment01_derek_dilger_aggregation.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> TIME #preview of data
#
# NameError: name 'TIME' is not defined

# %%
type(TIME)
# Out:
# pandas.core.frame.DataFrame

# %%
#TIME.plot(kind='bar')

# %%
TIME.index = pd.to_datetime(TIME['date'])

# %%
TIME = TIME.drop('date', axis=1)

# %%
TIME
# Out:
#             minsWorked
# date
# 2023-05-26         319
# 2023-05-27          12
# 2023-05-28           0
# 2023-05-29         127
# 2023-05-30           0
# ...                ...
# 2023-10-02         228
# 2023-10-03         399
# 2023-10-04          49
# 2023-10-05         426
# 2023-10-06         174
#
# [134 rows x 1 columns]

# %%
ax = TIME.plot(kind='line', figsize=(15,4))
ax.set_title("minutes \'worked\' each day")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\repo\csc177-group-project\assignment01_data_preprocessing_project\assignment01_derek_dilger_aggregation.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/repo/csc177-group-project/assignment01_data_preprocessing_project/assignment01_derek_dilger_aggregation.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> ax = TIME.plot(kind='line', figsize=(15,4))
#       <a href='vscode-notebook-cell:/d%3A/repo/csc177-group-project/assignment01_data_preprocessing_project/assignment01_derek_dilger_aggregation.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> ax.set_title("minutes \'worked\' each day")
#
# NameError: name 'TIME' is not defined

# %% [markdown]
# ## The above graph is not easy on the eyes.

# %%
weekly = TIME.groupby(pd.Grouper(freq='W')).sum()
ax = weekly.plot(kind='line', figsize =(15,4))
ax.set_title('minutes worked each week')
# Out:
# Text(0.5, 1.0, 'minutes worked each week')

# %% [markdown]
# ### The above graph is easier on the eyes than 'daily'. Given that there are only 134 days in the dataset, weekly is my personal favorite. Notice the week right before the semester starts? The dip in late September is due to a family reunion.

# %%
monthly = TIME.groupby(pd.Grouper(freq='M')).sum()
ax = monthly.plot(kind='line', figsize=(15,4))
ax.set_title('minutes worked each month')
# Out:
# Text(0.5, 1.0, 'minutes worked each month')

# %% [markdown]
# ### October isn't over!
